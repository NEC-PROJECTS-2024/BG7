# %%
import pandas as pd

# %%
data = pd.read_csv("train_loanPrediction.csv")

# %% [markdown]
# ### 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# ### 2. Check Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#        Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 1481  LP002689   Male     Yes         2.0  Not Graduate            No
# 1482  LP002690   Male      No         0.0      Graduate            No
# 1483  LP002692   Male     Yes         3.0      Graduate           Yes
# 1484  LP002693   Male     Yes         2.0      Graduate           Yes
# 1485  LP002697   Male      No         0.0      Graduate            No
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1481             2192             1742.0        45.0             360.0
# 1482             2500                0.0        55.0             360.0
# 1483             5677             1424.0       100.0             360.0
# 1484             7948             7166.0       480.0             360.0
# 1485             4680             2087.0         NaN             360.0
#
#       Credit_History Property_Area Loan_Status
# 1481             1.0     Semiurban           Y
# ...

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (1486, 13)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 1486
# Number of Columns 13

# %% [markdown]
# ### 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1486 entries, 0 to 1485
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            1486 non-null   object
#  1   Gender             1451 non-null   object
#  2   Married            1481 non-null   object
#  3   Dependents         1449 non-null   float64
#  4   Education          1486 non-null   object
#  5   Self_Employed      1414 non-null   object
#  6   ApplicantIncome    1486 non-null   int64
#  7   CoapplicantIncome  1486 non-null   float64
#  8   LoanAmount         1435 non-null   float64
#  9   Loan_Amount_Term   1462 non-null   float64
#  10  Credit_History     1360 non-null   float64
#  11  Property_Area      1486 non-null   object
#  12  Loan_Status        1486 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 151.1+ KB

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      1166
# Female     285
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x='Gender',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
data['Married'].value_counts()
# Out:
# Married
# Yes    949
# No     532
# Name: count, dtype: int64

# %%
sns.countplot(x='Married',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
data['Dependents'].value_counts()
# Out:
# Dependents
# 0.0    810
# 2.0    259
# 1.0    258
# 3.0    122
# Name: count, dtype: int64

# %%
sns.countplot(x='Dependents',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
data['Education'].value_counts()
# Out:
# Education
# Graduate        1148
# Not Graduate     338
# Name: count, dtype: int64

# %%
sns.countplot(x='Education',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
data['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     1208
# Yes     206
# Name: count, dtype: int64

# %%
sns.countplot(x='Self_Employed',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
data['ApplicantIncome'].value_counts()
# Out:
# ApplicantIncome
# 2500    24
# 2600    14
# 5000    13
# 8333    12
# 6000    12
#         ..
# 2577     1
# 6277     1
# 4860     1
# 1538     1
# 5849     1
# Name: count, Length: 505, dtype: int64

# %%
data['CoapplicantIncome'].value_counts()
# Out:
# CoapplicantIncome
# 0.0       645
# 2500.0     13
# 1666.0     13
# 2083.0     11
# 1750.0     11
#          ...
# 4486.0      1
# 1425.0      1
# 830.0       1
# 1041.0      1
# 2014.0      1
# Name: count, Length: 287, dtype: int64

# %%
data['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 110.0    47
# 100.0    40
# 120.0    38
# 113.0    33
# 160.0    30
#          ..
# 244.0     1
# 242.0     1
# 290.0     1
# 650.0     1
# 73.0      1
# Name: count, Length: 203, dtype: int64

# %%
data['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    1246
# 180.0     104
# 480.0      37
# 300.0      35
# 84.0       14
# 240.0       8
# 36.0        6
# 12.0        5
# 60.0        4
# 120.0       3
# Name: count, dtype: int64

# %%
sns.countplot(x='Loan_Amount_Term',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='count'>

# %%
data['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    1147
# 0.0     213
# Name: count, dtype: int64

# %%
sns.countplot(x='Credit_History',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
data['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    554
# Rural        478
# Urban        454
# Name: count, dtype: int64

# %%
sns.countplot(x='Property_Area',hue='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    1028
# N     458
# Name: count, dtype: int64

# %%
sns.countplot(x='Loan_Status',data=data)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
import matplotlib.pyplot as plt

target_column = 'Loan_Status'

# Create a pair plot
sns.pairplot(data, hue=target_column, diag_kind='kde', markers=["o", "s"])

# Show the plot
plt.show()
# Out:
# C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# Loan_ID                0
# Gender                35
# Married                5
# Dependents            37
# Education              0
# Self_Employed         72
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            51
# Loan_Amount_Term      24
# Credit_History       126
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
data.isnull().sum()*100 / len(data)
# Out:
# Loan_ID              0.000000
# Gender               2.355316
# Married              0.336474
# Dependents           2.489906
# Education            0.000000
# Self_Employed        4.845222
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.432032
# Loan_Amount_Term     1.615074
# Credit_History       8.479139
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
null_values = data.isnull()
plt.figure(figsize=(6, 4))
sns.heatmap(null_values, cmap='viridis', cbar=False)
plt.title('Null Values Heatmap')
plt.show()

# %% [markdown]
# ### 6. Handling The missing Values

# %%
data = data.drop('Loan_ID',axis=1)

# %%
data.head(1)
# Out:
#   Gender Married  Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0  Graduate            No             5849
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y

# %%
columns = ['Gender','Dependents','LoanAmount','Loan_Amount_Term']

# %%
data = data.dropna(subset=columns)

# %%
data.isnull().sum()*100 / len(data)
# Out:
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        5.200594
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       9.063893
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
data['Self_Employed'].mode()[0]
# Out:
# 'No'

# %%
data['Self_Employed'] =data['Self_Employed'].fillna(data['Self_Employed'].mode()[0])

# %%
data.isnull().sum()*100 / len(data)
# Out:
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       9.063893
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['Credit_History'].mode()[0]
# Out:
# 1.0

# %%
data['Credit_History'] =data['Credit_History'].fillna(data['Credit_History'].mode()[0])

# %%
data.isnull().sum()*100 / len(data)
# Out:
# Gender               0.0
# Married              0.0
# Dependents           0.0
# Education            0.0
# Self_Employed        0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# Property_Area        0.0
# Loan_Status          0.0
# dtype: float64

# %%
missing_percentage = (data.isnull().sum() * 100) / len(data)

# Create a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(missing_percentage.to_frame(), annot=True, cmap='viridis', cbar=False, fmt='.2f')
plt.title('Percentage of Missing Values Heatmap')
plt.show()

# %%
# Assuming 'Loan_Status' is the target variable, you might want to drop it for the correlation matrix
data_corr = data.drop('Loan_Status', axis=1)

# Calculate the correlation matrix
correlation_matrix = data_corr.corr(numeric_only=True)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Variables')
plt.show()

# %% [markdown]
# ### 7. Handling Categorical Columns

# %%
data.sample(5)
# Out:
#       Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 543     Male     Yes         1.0  Not Graduate            No             2239
# 932     Male     Yes         0.0      Graduate            No            11146
# 302   Female      No         0.0      Graduate            No             5000
# 1009    Male     Yes         0.0      Graduate            No             6333
# 1068  Female      No         0.0  Not Graduate            No             2213
#
#       CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 543              2524.0       128.0             360.0             1.0
# 932                 0.0       136.0             360.0             1.0
# 302                 0.0       132.0             360.0             1.0
# 1009             4583.0       259.0             360.0             1.0
# 1068                0.0        66.0             360.0             1.0
#
#      Property_Area Loan_Status
# 543          Urban           Y
# ...

# %%
data['Dependents'] =data['Dependents'].replace(to_replace="3+",value='4')

# %%
data['Dependents'].unique()
# Out:
# array([1., 0., 2., 3.])

# %%
data['Loan_Status'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
data['Gender'] = data['Gender'].map({'Male':1,'Female':0}).astype('int')
data['Married'] = data['Married'].map({'Yes':1,'No':0}).astype('int')
data['Education'] = data['Education'].map({'Graduate':1,'Not Graduate':0}).astype('int')
data['Self_Employed'] = data['Self_Employed'].map({'Yes':1,'No':0}).astype('int')
data['Property_Area'] = data['Property_Area'].map({'Rural':0,'Semiurban':2,'Urban':1}).astype('int')
data['Loan_Status'] = data['Loan_Status'].map({'Y':1,'N':0}).astype('int')

# %%
data.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1         1.0          1              0             4583
# 2       1        1         0.0          1              1             3000
# 3       1        1         0.0          0              0             2583
# 4       1        0         0.0          1              0             6000
# 5       1        1         2.0          1              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              1            1
# ...

# %% [markdown]
# ### 8. Store Feature Matrix In X And Response (Target) In Vector y

# %%
X = data.drop('Loan_Status',axis=1)

# %%
X
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1          1        1         1.0          1              0             4583
# 2          1        1         0.0          1              1             3000
# 3          1        1         0.0          0              0             2583
# 4          1        0         0.0          1              0             6000
# 5          1        1         2.0          1              1             5417
# ...      ...      ...         ...        ...            ...              ...
# 1480       0        0         0.0          0              0             3400
# 1481       1        1         2.0          0              0             2192
# 1482       1        0         0.0          1              0             2500
# 1483       1        1         3.0          1              1             5677
# 1484       1        1         2.0          1              1             7948
#
# ...

# %%
y = data['Loan_Status']

# %%
y
# Out:
# 1       0
# 2       1
# 3       1
# 4       1
# 5       1
#        ..
# 1480    0
# 1481    1
# 1482    1
# 1483    1
# 1484    1
# Name: Loan_Status, Length: 1346, dtype: int32

# %%
from imblearn.over_sampling import SMOTE
X,y=SMOTE().fit_resample(X,y)
X.shape,y.shape
# Out:
# ((1934, 11), (1934,))

# %%
y.value_counts()
# Out:
# Loan_Status
# 0    967
# 1    967
# Name: count, dtype: int64

# %%
data.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1         1.0          1              0             4583
# 2       1        1         0.0          1              1             3000
# 3       1        1         0.0          0              0             2583
# 4       1        0         0.0          1              0             6000
# 5       1        1         2.0          1              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              1            1
# ...

# %%
cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[cols]=st.fit_transform(X[cols])

# %%
X
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0          1        1     1.00000          1              0        -0.131076
# 1          1        1     0.00000          1              1        -0.389418
# 2          1        1     0.00000          0              0        -0.457472
# 3          1        0     0.00000          1              0         0.100176
# 4          1        1     2.00000          1              1         0.005031
# ...      ...      ...         ...        ...            ...              ...
# 1929       0        0     2.00000          1              0        -0.319733
# 1930       0        0     0.00000          0              0        -0.324139
# 1931       0        0     1.00000          1              0        -0.108228
# 1932       1        0     0.00000          0              0         0.105561
# 1933       1        1     1.49465          0              0        -0.473955
#
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1929    0
# 1930    0
# 1931    0
# 1932    0
# 1933    0
# Name: Loan_Status, Length: 1934, dtype: int32

# %% [markdown]
# ### 10. Splitting The Dataset Into The Training Set And Test Set & Applying K-Fold Cross Validation

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import numpy as np

# %%
model_df={}
def model_val(model,X,y):
    X_train,X_test,y_train,y_test=train_test_split(X,y,
                                                   test_size=0.20,
                                                   random_state=42)
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    print(f"{model} accuracy is {accuracy_score(y_test,y_pred)}")
    print(f"{model} Confusion Matrix is \n {confusion_matrix(y_test, y_pred)}")
    print(f"{model} Classification Report is \n {classification_report(y_test, y_pred)}")


   
    
    score = cross_val_score(model,X,y,cv=5)
    print(f"{model} Avg cross val score is {np.mean(score)}")
    model_df[model]=round(np.mean(score)*100,2)

# %%
model_df
# Out:
# {}

# %% [markdown]
# ### 11. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model_val(model,X,y)
# Out:
# LogisticRegression() accuracy is 0.7441860465116279
# LogisticRegression() Confusion Matrix is
#  [[136  62]
#  [ 37 152]]
# LogisticRegression() Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.79      0.69      0.73       198
#            1       0.71      0.80      0.75       189
#
#     accuracy                           0.74       387
#    macro avg       0.75      0.75      0.74       387
# weighted avg       0.75      0.74      0.74       387
#
# LogisticRegression() Avg cross val score is 0.762676895476028

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
log_reg_grid={"C":np.logspace(-4,4,20),
             "solver":['liblinear']}

# %%
rs_log_reg=RandomizedSearchCV(LogisticRegression(),
                   param_distributions=log_reg_grid,
                  n_iter=20,cv=5,verbose=True)

# %%
rs_log_reg.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']},
#                    verbose=True)

# %%
rs_log_reg.best_score_
# Out:
# 0.7600942549972554

# %%
rs_log_reg.best_params_
# Out:
# {'solver': 'liblinear', 'C': 4.281332398719396}

# %% [markdown]
# ### 12. SVC

# %%
from sklearn import svm
model = svm.SVC()
model_val(model,X,y)
# Out:
# SVC() accuracy is 0.8191214470284238
# SVC() Confusion Matrix is
#  [[148  50]
#  [ 20 169]]
# SVC() Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.88      0.75      0.81       198
#            1       0.77      0.89      0.83       189
#
#     accuracy                           0.82       387
#    macro avg       0.83      0.82      0.82       387
# weighted avg       0.83      0.82      0.82       387
#
# SVC() Avg cross val score is 0.8247325648337819

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
svc_grid = {'C':[0.25,0.50,0.75,1],"kernel":["linear"]}

# %%
rs_svc=RandomizedSearchCV(svm.SVC(),
                  param_distributions=svc_grid,
                   cv=5,
                   n_iter=20,
                  verbose=True)

# %%
rs_svc.fit(X,y)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:318: UserWarning: The total space of parameters 4 is smaller than n_iter=20. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=20,
#                    param_distributions={'C': [0.25, 0.5, 0.75, 1],
#                                         'kernel': ['linear']},
#                    verbose=True)

# %%
rs_svc.best_score_
# Out:
# 0.7445850236306917

# %%
rs_svc.best_params_
# Out:
# {'kernel': 'linear', 'C': 1}

# %% [markdown]
# ### 13. Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model_val(model,X,y)
# Out:
# DecisionTreeClassifier() accuracy is 0.9560723514211886
# DecisionTreeClassifier() Confusion Matrix is
#  [[186  12]
#  [  5 184]]
# DecisionTreeClassifier() Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       198
#            1       0.94      0.97      0.96       189
#
#     accuracy                           0.96       387
#    macro avg       0.96      0.96      0.96       387
# weighted avg       0.96      0.96      0.96       387
#
# DecisionTreeClassifier() Avg cross val score is 0.9601973464005035

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
DecisionTreeClassifier()
# Out:
# DecisionTreeClassifier()

# %%
dt_grid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None] + list(np.arange(1, 20)),
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

# %%
rs_dt=RandomizedSearchCV(DecisionTreeClassifier(),
                  param_distributions=dt_grid,
                   cv=5,
                   n_iter=20,
                  verbose=True)

# %%
rs_dt.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
# ...

# %%
X
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0          1        1     1.00000          1              0        -0.131076
# 1          1        1     0.00000          1              1        -0.389418
# 2          1        1     0.00000          0              0        -0.457472
# 3          1        0     0.00000          1              0         0.100176
# 4          1        1     2.00000          1              1         0.005031
# ...      ...      ...         ...        ...            ...              ...
# 1929       0        0     2.00000          1              0        -0.319733
# 1930       0        0     0.00000          0              0        -0.324139
# 1931       0        0     1.00000          1              0        -0.108228
# 1932       1        0     0.00000          0              0         0.105561
# 1933       1        1     1.49465          0              0        -0.473955
#
# ...

# %%
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1929    0
# 1930    0
# 1931    0
# 1932    0
# 1933    0
# Name: Loan_Status, Length: 1934, dtype: int32

# %%
rs_dt.best_score_
# Out:
# 0.9343508588718855

# %%
rs_dt.best_params_
# Out:
# {'splitter': 'random',
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': None,
#  'criterion': 'entropy'}

# %% [markdown]
# ### 14. Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
model =RandomForestClassifier()
model_val(model,X,y)
# Out:
# RandomForestClassifier() accuracy is 0.9689922480620154
# RandomForestClassifier() Confusion Matrix is
#  [[190   8]
#  [  4 185]]
# RandomForestClassifier() Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       198
#            1       0.96      0.98      0.97       189
#
#     accuracy                           0.97       387
#    macro avg       0.97      0.97      0.97       387
# weighted avg       0.97      0.97      0.97       387
#
# RandomForestClassifier() Avg cross val score is 0.9715735496913952

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
rf_grid={'n_estimators':np.arange(10,1000,10),
  'max_features':['auto','sqrt'],
 'max_depth':[None,3,5,10,20,30],
 'min_samples_split':[2,5,20,50,100],
 'min_samples_leaf':[1,2,5,10]
 }

# %%
rs_rf=RandomizedSearchCV(RandomForestClassifier(),
                  param_distributions=rf_grid,
                   cv=5,
                   n_iter=20,
                  verbose=True)

# %%
rs_rf.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 60 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
# ...

# %%
rs_rf.best_score_
# Out:
# 0.9353844506031516

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': 270,
#  'min_samples_split': 2,
#  'min_samples_leaf': 5,
#  'max_features': 'sqrt',
#  'max_depth': 20}

# %% [markdown]
# ### 15. Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
model =GradientBoostingClassifier()
model_val(model,X,y)
# Out:
# GradientBoostingClassifier() accuracy is 0.8992248062015504
# GradientBoostingClassifier() Confusion Matrix is
#  [[172  26]
#  [ 13 176]]
# GradientBoostingClassifier() Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90       198
#            1       0.87      0.93      0.90       189
#
#     accuracy                           0.90       387
#    macro avg       0.90      0.90      0.90       387
# weighted avg       0.90      0.90      0.90       387
#
# GradientBoostingClassifier() Avg cross val score is 0.9090144729619365

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
GradientBoostingClassifier()
# Out:
# GradientBoostingClassifier()

# %%
param_dist = {
    'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
    'n_estimators': np.arange(100, 1000, 100),
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10],
    'max_features': ['auto', 'sqrt', 'log2', None]
}

# %%
rs_gb=RandomizedSearchCV(GradientBoostingClassifier(),
                  param_distributions=param_dist,
                   cv=5,
                   n_iter=20,
                  verbose=True)

# %%
rs_gb.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 25 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\pujitha chilaka\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
# ...

# %%
rs_gb.best_score_
# Out:
# 0.9736393943045346

# %%
rs_gb.best_params_
# Out:
# {'n_estimators': 500,
#  'min_samples_split': 10,
#  'min_samples_leaf': 5,
#  'max_features': None,
#  'max_depth': 5,
#  'learning_rate': 0.2}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the models and their accuracies before and after hyperparameter tuning
models = ['Logistic Regression', 'SVM', 'Decision Tree', 'Random Forest', 'Gradient Boosting']
accuracies_before = [0.7441, 0.8191, 0.9560, 0.9689, 0.8992]
accuracies_after = [0.7626, 0.8247, 0.9601, 0.9715, 0.9090]  # Replace 'NaN' with the actual accuracy

# Create a DataFrame
df = pd.DataFrame({
    'Model': models,
    'Accuracy Before k-fold': accuracies_before,
    'Accuracy After k-fold': accuracies_after
})

# Plotting
plt.figure(figsize=(8, 6))

# Plot the accuracy before tuning
plt.plot(df['Model'], df['Accuracy Before k-fold'], marker='o', label='Before k-fold')

# Plot the accuracy after tuning
plt.plot(df['Model'], df['Accuracy After k-fold'], marker='o', label='After k-fold')

# Add labels and title
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracy Before and After k-fold')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# Display DataFrame
print(df)
# Out:
#                  Model  Accuracy Before k-fold  Accuracy After k-fold
# 0  Logistic Regression                  0.7441                 0.7626
# 1                  SVM                  0.8191                 0.8247
# 2        Decision Tree                  0.9560                 0.9601
# 3        Random Forest                  0.9689                 0.9715
# 4    Gradient Boosting                  0.8992                 0.9090

# %%
models = ['LR','SVM','DT','RF','GB']
accuracy = [0.7626,0.8247,0.9601,0.9715,0.9090]
plt.bar(models,accuracy)
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# ### 17. Save The Model

# %%
X = data.drop('Loan_Status',axis=1)
y = data['Loan_Status']

# %%
rf = RandomForestClassifier(n_estimators=270,
 min_samples_split=5,
 min_samples_leaf=5,
 max_features='sqrt',
 max_depth=5)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=5, min_samples_split=5,
#                        n_estimators=270)

# %% [markdown]
# # GUI

# %%
import pickle
pickle.dump(model, open('model.pkl','wb'))
